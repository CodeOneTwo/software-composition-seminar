# %%
import pickle
import pandas as pd
from github import Github
import os
g = Github(os.environ['GITHUBTOKEN'])

# %%
def save_to_file(data, name='repos'):
    with open(f'./data/{name}.pickle', 'wb') as file:
        pickle.dump(data, file)

# %%
with open('./data/repo_stats.pickle', 'rb') as file:
    repo_stats = pickle.load(file)
df = pd.DataFrame(repo_stats['repos'])
df.head(10)
# Out:
#                    name                      full_name  \
# 0                 linux                 torvalds/linux
# 1  java-design-patterns  iluwatar/java-design-patterns
# 2                jekyll                  jekyll/jekyll
# 3             tutorials               eugenp/tutorials
# 4                consul               hashicorp/consul
# 5                   hub                     github/hub
# 6              influxdb            influxdata/influxdb
# 7                kibana                 elastic/kibana
# 8              diaspora              diaspora/diaspora
# 9                server               nextcloud/server
#
#                                                 url   fork  num_forks  \
# 0                 https://github.com/torvalds/linux  False      34526
# 1  https://github.com/iluwatar/java-design-patterns  False      19820
# 2                  https://github.com/jekyll/jekyll  False       9115
# 3               https://github.com/eugenp/tutorials  False      38199
# 4               https://github.com/hashicorp/consul  False       3544
# 5                     https://github.com/github/hub  False       2141
# 6            https://github.com/influxdata/influxdb  False       2825
# 7                 https://github.com/elastic/kibana  False       6167
# 8              https://github.com/diaspora/diaspora  False       2915
# 9               https://github.com/nextcloud/server  False       2291
#
#                                     num_contributors  num_commits  num_stars  \
# 0  [403 {"message": "The history or contributor l...       968187     101487
# 1                                                212         2978      62226
# 2                                                402        11200      41693
# 3                                                323        21061      23873
# 4                                                379        13255      20701
# 5                                                218         3306      20563
# 6                                                323        34431      20017
# 7                                                353        38439      15187
# 8                                                281        20279      12570
# 9                                                378        56380      12369
#
#    num_watchers                                  commit_activities  \
# 0          7580  [{'total': 1964, 'week': 1575763200, 'days': [...
# 1          3993  [{'total': 4, 'week': 1575763200, 'days': [0, ...
# 2          1473  [{'total': 5, 'week': 1575763200, 'days': [0, ...
# 3          1540  [{'total': 81, 'week': 1575763200, 'days': [17...
# 4           983  [{'total': 35, 'week': 1575763200, 'days': [0,...
# 5           477  [{'total': 2, 'week': 1575763200, 'days': [0, ...
# 6           755  [{'total': 49, 'week': 1575763200, 'days': [0,...
# 7           847  [{'total': 168, 'week': 1575763200, 'days': [0...
# 8           502  [{'total': 0, 'week': 1575763200, 'days': [0, ...
# 9           509  [{'total': 57, 'week': 1575763200, 'days': [10...
#
#    issues_closed  issues_all  pull_requests_closed  pull_requests_all  \
# 0            440         761                   440                761
# 1           1322        1583                   905                938
# 2           8185        8334                  3944               4014
# 3          10260       10291                  9834               9855
# 4           8415        9211                  5041               5146
# 5           2325        2567                   739                781
# 6          18772       20021                  9096               9218
# 7          76758       84422                 54235              54703
# 8           7702        8151                  3491               3521
# 9          21473       24118                 12535              12705
#
#    comments                                          languages  \
# 0      1172  {'C': 853161843, 'C++': 11419111, 'Assembly': ...
# 1        39  {'Java': 3390250, 'HTML': 20964, 'CSS': 11102,...
# 2       556  {'Ruby': 696738, 'Gherkin': 224137, 'JavaScrip...
# 3        26  {'Java': 18787946, 'JavaScript': 2946071, 'HTM...
# 4       195  {'Go': 10117251, 'JavaScript': 1082533, 'SCSS'...
# 5       178  {'Go': 358904, 'Gherkin': 289265, 'Shell': 392...
# 6       351  {'Go': 14021584, 'TypeScript': 3730682, 'JavaS...
# 7       366  {'TypeScript': 76447863, 'JavaScript': 1268035...
# 8      1727  {'Ruby': 2291824, 'JavaScript': 754337, 'Haml'...
# 9       140  {'PHP': 19363568, 'JavaScript': 10473779, 'Vue...
#
#   date_of_last_commit
# 0                None
# 1                None
# 2                None
# 3                None
# 4                None
# 5                None
# 6                None
# 7                None
# 8                None
# 9                None

# %%
from fetch_data.repo_stats import get_feature_files

for repo_data in repo_stats['repos'][:10]:
    repo = g.get_repo(repo_data['full_name'])
    repo_data["feature_files"] = get_feature_files(repo, g)
    
repo_stats['repos'][:10]

# %%
save_to_file(repo_stats['repos'][:10], name='manual_feature_file_list')
